# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielalastra/oprah_winfrey/blob/main/Oprah_Wiki_collect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install wikipedia
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11695 sha256=b1248e3f7bb74944596155b3aad01352f0886d9fd893c044e835bb15cd6ccf33
#   Stored in directory: /root/.cache/pip/wheels/15/93/6d/5b2c68b8a64c7a7a04947b4ed6d89fb557dcc6bc27d1d7f3ba
# Successfully built wikipedia
# ...

# %%
import wikipedia

# %%
print(wikipedia.search('Oprah'))
# Out:
# ['Oprah Winfrey', 'The Oprah Winfrey Show', 'Oprah Winfrey Network', 'O, The Oprah Magazine', 'Oprah Winfrey Leadership Academy for Girls', "Oprah's Book Club", 'Harpo Productions', 'Johnny Depp', 'Oprah with Meghan and Harry', 'List of awards and nominations received by Oprah Winfrey']

# %%
summary = wikipedia.summary('Oprah Winfrey')

# %%
print(summary)
# Out:
# Oprah Gail Winfrey (; born  Orpah Gail Winfrey; January 29, 1954) is an American talk show host, television producer, actress, author, and philanthropist. She is best known for her talk show, The Oprah Winfrey Show, broadcast from Chicago, which was the highest-rated television program of its kind in history and ran in national syndication for 25 years, from 1986 to 2011. Dubbed the "Queen of All Media", she was the richest African-American of the 20th century, was once the world's only black billionaire, and the greatest black philanthropist in U.S. history. By 2007, she was sometimes ranked as the most influential woman in the world.Winfrey was born into poverty in rural Mississippi to a single teenage mother and later raised in inner-city Milwaukee. She has stated that she was molested during her childhood and early teenage years and became pregnant at 14; her son was born prematurely and died in infancy. Winfrey was then sent to live with the man she calls her father, Vernon Winf
# ...

# %%
page = wikipedia.page('Oprah Winfrey')

# %%
print(page.content)
# Out:
# Oprah Gail Winfrey (; born  Orpah Gail Winfrey; January 29, 1954) is an American talk show host, television producer, actress, author, and philanthropist. She is best known for her talk show, The Oprah Winfrey Show, broadcast from Chicago, which was the highest-rated television program of its kind in history and ran in national syndication for 25 years, from 1986 to 2011. Dubbed the "Queen of All Media", she was the richest African-American of the 20th century, was once the world's only black billionaire, and the greatest black philanthropist in U.S. history. By 2007, she was sometimes ranked as the most influential woman in the world.Winfrey was born into poverty in rural Mississippi to a single teenage mother and later raised in inner-city Milwaukee. She has stated that she was molested during her childhood and early teenage years and became pregnant at 14; her son was born prematurely and died in infancy. Winfrey was then sent to live with the man she calls her father, Vernon Winf
# ...

# %%
print(page.url)
# Out:
# https://en.wikipedia.org/wiki/Oprah_Winfrey

# %%
import pandas as pd

# %%
pip install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Oprah_Winfrey')

# %%
df
# Out:
# [              Oprah Winfrey                                    Oprah Winfrey.1
#  0   Winfrey in October 2014                            Winfrey in October 2014
#  1                      Born  Orpah Gail Winfrey (age 68)Kosciusko, Mississi...
#  2                Alma mater                         Tennessee State University
#  3                Occupation        TV hostactressproducermedia executiveauthor
#  4              Years active                                       1973–present
#  5                     Works                                     Media projects
#  6                     Title  Chairwoman and CEO of Harpo Productions (1986–...
#  7           Political party                                        Independent
#  8                Partner(s)                      Stedman Graham (1986–present)
#  9                  Children                                               1[1]
#  10                   Awards                                          Full list
# ...

# %%
len(df)
# Out:
# 46

# %%
df[0]
# Out:
#               Oprah Winfrey                                    Oprah Winfrey.1
# 0   Winfrey in October 2014                            Winfrey in October 2014
# 1                      Born  Orpah Gail Winfrey (age 68)Kosciusko, Mississi...
# 2                Alma mater                         Tennessee State University
# 3                Occupation        TV hostactressproducermedia executiveauthor
# 4              Years active                                       1973–present
# 5                     Works                                     Media projects
# 6                     Title  Chairwoman and CEO of Harpo Productions (1986–...
# 7           Political party                                        Independent
# 8                Partner(s)                      Stedman Graham (1986–present)
# 9                  Children                                               1[1]
# 10                   Awards                                          Full list
# ...

# %%
df[1]
# Out:
#     0                                                  1
# 0 NaN  This section of a biography of a living person...

# %%
df[2]
# Out:
#        Year                                      Title  \
# 0      1985                           The Color Purple
# 1      1986                                 Native Son
# 2      1989                The Women of Brewster Place
# 3      1990                             Brewster Place
# 4      1992                                    Lincoln
# 5      1992                 There Are No Children Here
# 6      1997                                      Ellen
# 7      1997                     Before Women Had Wings
# 8      1998                                    Beloved
# 9      1999                         Our Friend, Martin
# 10     2006                            Charlotte's Web
# 11     2007                                  Bee Movie
# 12     2009                  The Princess and the Frog
# 13     2010                              Sesame Street
# 14     2013                                 The Butler
# 15     2014                                      Selma
# ...

# %%
actress = df[2]

# %%
df[3]
# Out:
#             Year                                              Title  \
# 0           1986                                Saturday Night Live
# 1      1986–2011                             The Oprah Winfrey Show
# 2           1987                         Throw Momma from the Train
# 3           1990                                     Gabriel's Fire
# 4           1992                        The Fresh Prince of Bel-Air
# 5           1995                                  All-American Girl
# 6           1999                                   Home Improvement
# 7           1999                                       The Hughleys
# 8           2005  Desperate Housewives: Oprah Winfrey Is the New...
# 9           2007                                   Ocean's Thirteen
# 10          2008                                            30 Rock
# 11       2011–18                               Oprah's Master Class
# 12       2011–14                                  Oprah's Lifeclass
# ...

# %%
asherself = df[3]

# %%
df[7]
# Out:
#   vteCecil B. DeMille Award                        vteCecil B. DeMille Award.1
# 0                     1950s  Cecil B. DeMille (1952) Walt Disney (1953) Dar...
# 1                     1960s  Bing Crosby (1960) Fred Astaire (1961) Judy Ga...
# 2                     1970s  Joan Crawford (1970) Frank Sinatra (1971) Alfr...
# 3                     1980s  Henry Fonda (1980) Gene Kelly (1981) Sidney Po...
# 4                     1990s  Audrey Hepburn (1990) Jack Lemmon (1991) Rober...
# 5                     2000s  Barbra Streisand (2000) Al Pacino (2001) Harri...
# 6                     2010s  Martin Scorsese (2010) Robert De Niro (2011) M...
# 7                     2020s  Tom Hanks (2020) Jane Fonda (2021) No Award (2...

# %%
df2 = pd.read_html('https://en.wikipedia.org/wiki/List_of_awards_and_nominations_received_by_Oprah_Winfrey')

# %%
df2[2]
# Out:
#   Awards and nominations Awards and nominations.1 Awards and nominations.2  \
# 0                  Award                     Wins              Nominations
# 1         Academy Awards                        0                        2
# 2    Daytime Emmy Awards                       18                       26
# 3          Golden Globes                        0                        1
# 4     NAACP Image Awards                       12                       25
# 5  Primetime Emmy Awards                        1                        7
# 6            Tony Awards                        1                        2
# 7                    NaN                      NaN                      NaN
#
#    Awards and nominations.3
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN

# %%
df2[3]
# Out:
#    Year    Nominated work                          Category     Result
# 0  1985  The Color Purple           Best Supporting Actress  Nominated
# 1  2011               NaN  Jean Hersholt Humanitarian Award        Won
# 2  2014             Selma                      Best Picture  Nominated

# %%
df2[4]
# Out:
#    Year    Nominated work                                           Category  \
# 0  1986  The Color Purple  Golden Globe Award for Best Supporting Actress...
# 1  2018           Herself                Golden Globe Cecil B. DeMille Award
#
#       Result
# 0  Nominated
# 1        Won

# %%
df2[5]
# Out:
#    Year                        Nominated work  \
# 0  1989           The Women of Brewster Place
# 1  1994     Michael Jackson Talks... To Oprah
# 2  2000                  Tuesdays with Morrie
# 3  2002                                   NaN
# 4  2013                  Oprah's Master Class
# 5  2014                    Running from Crazy
# 6  2017  The Immortal Life of Henrietta Lacks
# 7  2019                      When They See Us
# 8  2021           Oprah with Meghan and Harry
#
#                                           Category     Result
# 0                  Outstanding Comedy/Drama Series  Nominated
# 1                Outstanding Informational Special  Nominated
# 2            Outstanding Made for Television Movie        Won
# 3                      Bob Hope Humanitarian Award        Won
# 4        Outstanding Information Special or Series  Nominated
# 5    Outstanding Documentary or Nonfiction Special  Nominated
# 6                     Outstanding Television Movie  Nominated
# ...

# %%
df2[6]
# Out:
#    Year    Nominated work              Category     Result
# 0  2006  The Color Purple          Best Musical  Nominated
# 1  2016  The Color Purple  Best Musical Revival        Won

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-6b0270952584> in <module>()
# ----> 1 df2[10]
#
# IndexError: list index out of range
